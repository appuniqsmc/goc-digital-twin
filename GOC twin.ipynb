# %%
test_patient = data.iloc[[0]].drop(columns=["target_GoC"])

prediction, probability = digital_twin_predict(test_patient)

print("Prediction:", prediction)
print("Probability:", probability)
# Out:
# Prediction: Comfort Care
# Probability: {'Comfort Care': np.float64(0.835), 'Full Care': np.float64(0.015), 'Limited Care': np.float64(0.15)}
